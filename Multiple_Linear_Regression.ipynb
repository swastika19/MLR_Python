# %% [markdown]
# **Importing the Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Importing the Dataset**

# %%
dataset = pd.read_csv("ToyotaCorolla(1).csv")
dataset
# Out:
#         Id  ... Weight
# 0        1  ...   1165
# 1        2  ...   1165
# 2        3  ...   1165
# 3        4  ...   1165
# 4        5  ...   1170
# ...    ...  ...    ...
# 1431  1432  ...   1025
# 1432  1433  ...   1015
# 1433  1434  ...   1015
# 1434  1435  ...   1015
# 1435  1436  ...   1114
#
# [1436 rows x 13 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
dataset1 = dataset.drop(['Id', 'Model'], axis = 1)

# %%
dataset1.head(10)
# Out:
#    Price  Age_08_04     KM Fuel_Type  ...    cc  Doors  Quarterly_Tax  Weight
# 0  13500         23  46986    Diesel  ...  2000      3            210    1165
# 1  13750         23  72937    Diesel  ...  2000      3            210    1165
# 2  13950         24  41711    Diesel  ...  2000      3            210    1165
# 3  14950         26  48000    Diesel  ...  2000      3            210    1165
# 4  13750         30  38500    Diesel  ...  2000      3            210    1170
# 5  12950         32  61000    Diesel  ...  2000      3            210    1170
# 6  16900         27  94612    Diesel  ...  2000      3            210    1245
# 7  18600         30  75889    Diesel  ...  2000      3            210    1245
# 8  21500         27  19700    Petrol  ...  1800      3            100    1185
# 9  12950         23  71138    Diesel  ...  1900      3            185    1105
#
# [10 rows x 11 columns]

# %%
dataset1.tail()
# Out:
#       Price  Age_08_04     KM Fuel_Type  ...    cc  Doors  Quarterly_Tax  Weight
# 1431   7500         69  20544    Petrol  ...  1300      3             69    1025
# 1432  10845         72  19000    Petrol  ...  1300      3             69    1015
# 1433   8500         71  17016    Petrol  ...  1300      3             69    1015
# 1434   7250         70  16916    Petrol  ...  1300      3             69    1015
# 1435   6950         76      1    Petrol  ...  1600      5             19    1114
#
# [5 rows x 11 columns]

# %%
dataset2 = pd.get_dummies(dataset1)

# %%
dataset2
# Out:
#       Price  Age_08_04  ...  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0     13500         23  ...                 1                 0
# 1     13750         23  ...                 1                 0
# 2     13950         24  ...                 1                 0
# 3     14950         26  ...                 1                 0
# 4     13750         30  ...                 1                 0
# ...     ...        ...  ...               ...               ...
# 1431   7500         69  ...                 0                 1
# 1432  10845         72  ...                 0                 1
# 1433   8500         71  ...                 0                 1
# 1434   7250         70  ...                 0                 1
# 1435   6950         76  ...                 0                 1
#
# [1436 rows x 13 columns]

# %%
dataset2.to_csv('Toyota_Price.csv')

# %%
dataset2['Doors'].value_counts()
# Out:
# 5    674
# 3    622
# 4    138
# 2      2
# Name: Doors, dtype: int64

# %%
X = dataset2.iloc[:, 1:13]
X
# Out:
#       Age_08_04     KM   HP  ...  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0            23  46986   90  ...              0                 1                 0
# 1            23  72937   90  ...              0                 1                 0
# 2            24  41711   90  ...              0                 1                 0
# 3            26  48000   90  ...              0                 1                 0
# 4            30  38500   90  ...              0                 1                 0
# ...         ...    ...  ...  ...            ...               ...               ...
# 1431         69  20544   86  ...              0                 0                 1
# 1432         72  19000   86  ...              0                 0                 1
# 1433         71  17016   86  ...              0                 0                 1
# 1434         70  16916   86  ...              0                 0                 1
# ...

# %%
X1=dataset2.iloc[0:5,0:5]
X1
# Out:
#    Price  Age_08_04     KM  HP  Met_Color
# 0  13500         23  46986  90          1
# 1  13750         23  72937  90          1
# 2  13950         24  41711  90          1
# 3  14950         26  48000  90          0
# 4  13750         30  38500  90          0

# %%
Y= dataset2.iloc[:, 0]
Y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %%
dataset2.describe()
# Out:
#               Price    Age_08_04  ...  Fuel_Type_Diesel  Fuel_Type_Petrol
# count   1436.000000  1436.000000  ...       1436.000000       1436.000000
# mean   10730.824513    55.947075  ...          0.107939          0.880223
# std     3626.964585    18.599988  ...          0.310411          0.324814
# min     4350.000000     1.000000  ...          0.000000          0.000000
# 25%     8450.000000    44.000000  ...          0.000000          1.000000
# 50%     9900.000000    61.000000  ...          0.000000          1.000000
# 75%    11950.000000    70.000000  ...          0.000000          1.000000
# max    32500.000000    80.000000  ...          1.000000          1.000000
#
# [8 rows x 13 columns]

# %% [markdown]
# **Data Pre-Processing**

# %% [markdown]
# Finding the missing values

# %%
dataset2.isnull().sum()

#Checking for missing values
# Out:
# Price               0
# Age_08_04           0
# KM                  0
# HP                  0
# Met_Color           0
# Automatic           0
# cc                  0
# Doors               0
# Quarterly_Tax       0
# Weight              0
# Fuel_Type_CNG       0
# Fuel_Type_Diesel    0
# Fuel_Type_Petrol    0
# dtype: int64

# %% [markdown]
# **Exploratory Data Analysis(EDA)**

# %%
dataset.count()
# Out:
# Id               1436
# Model            1436
# Price            1436
# Age_08_04        1436
# KM               1436
# Fuel_Type        1436
# HP               1436
# Met_Color        1436
# Automatic        1436
# cc               1436
# Doors            1436
# Quarterly_Tax    1436
# Weight           1436
# dtype: int64

# %%
dataset.describe()
# Out:
#                 Id         Price  ...  Quarterly_Tax      Weight
# count  1436.000000   1436.000000  ...    1436.000000  1436.00000
# mean    718.500000  10730.824513  ...      87.122563  1072.45961
# std     414.681806   3626.964585  ...      41.128611    52.64112
# min       1.000000   4350.000000  ...      19.000000  1000.00000
# 25%     359.750000   8450.000000  ...      69.000000  1040.00000
# 50%     718.500000   9900.000000  ...      85.000000  1070.00000
# 75%    1077.250000  11950.000000  ...      85.000000  1085.00000
# max    1436.000000  32500.000000  ...     283.000000  1615.00000
#
# [8 rows x 11 columns]

# %%
x1= dataset2.iloc[:, 1]
x2= dataset2.iloc[:, 2]

plt.scatter(x1, x2, s=30, color = 'red')
plt.xlabel('Age')
plt.ylabel('Kilometer')
 #scatter_plot
# Out:
# Text(0, 0.5, 'Kilometer')

# %%
x3= dataset2.iloc[:, 0]
x4= dataset2.iloc[:, 1]

plt.scatter(x3, x4, s=30, color = 'Green')
plt.xlabel('Price')
plt.ylabel('Age')
 #scatter_plot
# Out:
# Text(0, 0.5, 'Age')

# %%
x5= dataset2.iloc[:, 0]
x6= dataset2.iloc[:, 2]

plt.scatter(x5, x6, s=30, color = 'dodgerblue')
plt.xlabel('Price')
plt.ylabel('Kilometer')
 #scatter_plot
# Out:
# Text(0, 0.5, 'Kilometer')

# %%
x7= dataset2.iloc[:, 0]
x8= dataset2.iloc[:, 3]

plt.scatter(x7, x8, s=30, color = 'brown')
plt.xlabel('Price')
plt.ylabel('HP')
 #scatter_plot
# Out:
# Text(0, 0.5, 'HP')

# %%
x9= dataset2.iloc[:, 0]
x10= dataset2.iloc[:, 6]

plt.scatter(x9, x10, s=30, color = 'pink')
plt.xlabel('Price')
plt.ylabel('CC')
 #scatter_plot
# Out:
# Text(0, 0.5, 'CC')

# %%
x11= dataset2.iloc[:, 0]
x12= dataset2.iloc[:, 10]

plt.scatter(x11, x12, s=30, color = 'cyan')
plt.xlabel('Price')
plt.ylabel('CNG')
plt.colorbar()
 #scatter_plot

# %%
x13= dataset2.iloc[:, 0]
x14= dataset2.iloc[:, 11]

plt.scatter(x13, x14, s=30, color = 'grey')
plt.xlabel('Price')
plt.ylabel('Diesel')
 #scatter_plot
# Out:
# Text(0, 0.5, 'Diesel')

# %%
x15= dataset2.iloc[:, 0]
x16= dataset2.iloc[:, 12]

plt.scatter(x15, x16, s=30, color = 'purple')
plt.xlabel('Price')
plt.ylabel('Petrol')
 #scatter_plot
# Out:
# Text(0, 0.5, 'Petrol')

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
fig_dims = (12, 10)
fig, a = plt.subplots(figsize= fig_dims)
box1 = sns.boxplot(ax =a, data = dataset2, orient = "v")
#boxplot

# %%
dimension = (10, 8)
fig1, a1 = plt.subplots(figsize= dimension)
box2 = sns.boxplot(ax = a1, x = "Doors", y = "Price", hue = "Met_Color", data = dataset2, palette = "Set2" )

# %%
dimension1 = (10, 8)

f, a2 = plt.subplots(figsize= dimension1)

box1 = sns.boxplot(ax = a2, x = "Doors", y = "Price", data = dataset2)

# %% [markdown]
# Correlation Matrix and Visualisations

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
corr = dataset2.corr()
#Plot figsize
fig, ax = plt.subplots(figsize=(12, 12))
#Generate Heat Map, allow annotations and place floats in map
mask = np.tril(corr)
sns.heatmap(corr, annot=True, mask=mask)
#Apply xticks
plt.xticks(range(len(corr.columns)), corr.columns);
#Apply yticks
plt.yticks(range(len(corr.columns)), corr.columns)
#show plot
plt.show()

# %%
corr1 = dataset2.corr()
#Plot figsize
fig, ax = plt.subplots(figsize=(12, 12))
#Generate Heat Map, allow annotations and place floats in map
mat = np.triu(corr1)
sns.heatmap(corr1, annot=True, mask=mat)
#Apply xticks
plt.xticks(range(len(corr1.columns)), corr1.columns);
#Apply yticks
plt.yticks(range(len(corr1.columns)), corr1.columns)
#show plot
plt.show()

# %% [markdown]
# **Splitting the Data set into Training set and Test set**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# **Linear Regression Model**

# %%
#Importing required Packages
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

#Initialise Model
regression_model = LinearRegression()

regression_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x= X_train.iloc[:, 2]
x
# Out:
# 609      72
# 511     110
# 878      86
# 960      86
# 303      97
#        ...
# 763      86
# 835     110
# 1216     72
# 559     110
# 684     110
# Name: HP, Length: 1148, dtype: int64

# %%
#Line of Best Fit

plt.figure(figsize=(14,8)) # set the size of the graph
a = sns.regplot(data=dataset2, x='KM', y='Price')

# %%
plt.figure(figsize=(12,6)) # set the size of the graph
a = sns.regplot(data=dataset2, x='HP', y='Price')

# %% [markdown]
# Predicting Prices from Training Set

# %%
Y_pred = regression_model.predict(X_train)
Y_pred
# Out:
# array([ 6914.78236025, 11931.84859225,  9218.36008575, ...,
#         8728.8515029 , 12280.94750474,  8892.19717689])

# %%
rmse = mean_squared_error(Y_train, Y_pred)
r2 = r2_score(Y_train, Y_pred)

# %%
print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [-1.21798901e+02 -1.65888200e-02  5.99135965e+01  8.81116540e+01
#   2.86621096e+02 -4.20715603e+00 -2.46636918e+01  9.99306887e+00
#   1.82893473e+01 -2.11477246e+03  1.85935966e+03  2.55412800e+02]
# Intercept: -1651.5896868374166
# Root mean squared error:  1612089.2225542667
# R2 score:  0.8789911241313856

# %%
plt.figure(figsize=(10,10)) # set the size of the graph
plt.scatter(Y_train, Y_pred, color='black')
plt.xlabel('Original Values')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %% [markdown]
# ***OLS Linear Regression Model***

# %%
pip install statsmodels

# %%
import statsmodels.formula.api as smf

# %%
car_price = smf.ols("""Price ~ Age_08_04 + KM + HP + Met_Color + Automatic + cc + Doors + Quarterly_Tax + Weight + Fuel_Type_CNG + Fuel_Type_Diesel + Fuel_Type_Petrol""", data = dataset2).fit()

# %%
car_price.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Mon, 10 May 2021   Prob (F-statistic):               0.00
# Time:                        16:21:02   Log-Likelihood:                -12347.
# No. Observations:                1436   AIC:                         2.472e+04
# Df Residuals:                    1424   BIC:                         2.478e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
